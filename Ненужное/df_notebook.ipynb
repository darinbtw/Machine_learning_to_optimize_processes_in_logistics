# %%
# !pip3 install numpy
# !pip3 install pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#loading the dataset and reading the csv file
data = './exel_files/smart_logistics_dataset.csv'
data1 = pd.read_csv(data)

#first 5 rows of the dataset
data1.head(15)
# Out:
#               Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 0   2024-03-20 00:11:14   Truck_7  -65.7383    11.2497              390
# 1   2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 2   2024-07-29 18:42:48  Truck_10   54.9232    79.5455              190
# 3   2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 4   2024-09-27 15:52:58   Truck_7  -65.8477    47.9468              480
# 5   2024-09-17 06:02:15   Truck_7   73.3312    46.5831              118
# 6   2024-02-05 08:38:56   Truck_4   27.9307   147.5317              480
# 7   2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 8   2024-01-18 08:27:04   Truck_9  -83.6737   -31.7125              245
# 9   2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 10  2024-01-09 23:19:43   Truck_9   82.9633  -154.5274              319
# 11  2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                1000 non-null   object
#  1   Asset_ID                 1000 non-null   object
#  2   Latitude                 1000 non-null   float64
#  3   Longitude                1000 non-null   float64
#  4   Inventory_Level          1000 non-null   int64
#  5   Shipment_Status          1000 non-null   object
#  6   Temperature              1000 non-null   float64
#  7   Humidity                 1000 non-null   float64
#  8   Traffic_Status           1000 non-null   object
#  9   Waiting_Time             1000 non-null   int64
#  10  User_Transaction_Amount  1000 non-null   int64
#  11  User_Purchase_Frequency  1000 non-null   int64
#  12  Logistics_Delay_Reason   737 non-null    object
#  13  Asset_Utilization        1000 non-null   float64
# ...

# %%
data1.describe()
# Out:
#           Latitude    Longitude  Inventory_Level  Temperature     Humidity  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1000.000000
# mean     -1.360093     0.837049       297.915000    23.893900    65.042200
# std      51.997183   104.843618       113.554773     3.322178     8.753765
# min     -89.791500  -179.820200       100.000000    18.000000    50.000000
# 25%     -46.167975   -88.448075       201.000000    21.200000    57.200000
# 50%      -4.503150     0.678300       299.000000    23.800000    65.200000
# 75%      44.502800    88.156450       399.000000    26.600000    72.400000
# max      89.870100   179.923700       500.000000    30.000000    80.000000
#
#        Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# count   1000.000000              1000.000000              1000.000000
# mean      35.062000               299.055000                 5.513000
# std       14.477768               117.787792                 2.935379
# ...

# %%
import reverse_geocode

#get location from coordinates
def get_location_name(lat, lon):
    location = reverse_geocode.search([(lat, lon)])
    # print('location: ', location)
    return f'{location[0]['city']}, {location[0]['country']}'

data1['Location'] = data1.apply(lambda row: get_location_name(row['Latitude'], row['Longitude']), axis=1)

# %%
data1['Location']
# Out:
# 0                          Pearly Beach, South Africa
# 1                               Lompoc, United States
# 2                       Ubinskoye, Russian Federation
# 3                             Murillo el Fruto, Spain
# 4      Port-aux-Français, French Southern Territories
#                             ...
# 995                        Dikson, Russian Federation
# 996                       Mata-Utu, Wallis and Futuna
# 997    Port-aux-Français, French Southern Territories
# 998                          Struisbaai, South Africa
# 999                                 Hay River, Canada
# Name: Location, Length: 1000, dtype: object

# %%
#convert 'Timestamp' column to datetime format
data1['Timestamp'] = pd.to_datetime(data1['Timestamp'])

# %%
#how much trucks are we having
data1['Asset_ID'].value_counts().plot(kind='bar', title='Number of trucks in the dataset', color='green')
# Out:
# <Axes: title={'center': 'Number of trucks in the dataset'}, xlabel='Asset_ID'>

# %%
data1['Inventory_Level'].plot(kind='hist', title='Распределения уровня запасов')
# Out:
# <Axes: title={'center': 'Распределения уровня запасов'}, ylabel='Frequency'>

# %%
#Статус отгрузки
data1['Shipment_Status'].value_counts().plot(kind='bar', title='Статус отгрузки', color='Green')
# Out:
# <Axes: title={'center': 'Статус отгрузки'}, xlabel='Shipment_Status'>

# %%
data1['Temperature'].plot(kind='hist', title='Распределение температуры', ylabel='Частота')
# Out:
# <Axes: title={'center': 'Распределение температуры'}, ylabel='Частота'>

# %%
#checking location column
data1.head(5)
# Out:
#             Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 0 2024-03-20 00:11:14   Truck_7  -65.7383    11.2497              390
# 1 2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 2 2024-07-29 18:42:48  Truck_10   54.9232    79.5455              190
# 3 2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 4 2024-09-27 15:52:58   Truck_7  -65.8477    47.9468              480
#
#   Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 0         Delayed         27.0      67.8         Detour            38
# 1      In Transit         22.5      54.3          Heavy            16
# 2      In Transit         25.2      62.2         Detour            34
# 3       Delivered         25.4      52.3          Heavy            37
# 4         Delayed         20.5      57.2          Clear            56
#
#    User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# ...

# %%
data1['Humidity'].plot(kind='hist', title='Распределение влажности', ylabel='Частота', color='green')
# Out:
# <Axes: title={'center': 'Распределение влажности'}, ylabel='Частота'>

# %%
data1['Traffic_Status'].value_counts().plot(kind='bar', title='Распределение статуса трафика', color='orange', xlabel='Трафик статус')
# Out:
# <Axes: title={'center': 'Распределение статуса трафика'}, xlabel='Трафик статус'>

# %%
data1['Waiting_Time'].plot(kind='hist', title='Waiting time distribution', ylabel='Кол-во ожидания в минутах', xlabel='Время ожидания (мин)')
# Out:
# <Axes: title={'center': 'Распределение времени ожидания'}, xlabel='Время ожидания (мин)', ylabel='Кол-во ожидания в минутах'>

# %%
data1['User_Transaction_Amount'].plot(kind='hist', title='User Transaction Amount')
# Out:
# <Axes: title={'center': 'User Transaction Amount'}, ylabel='Frequency'>

# %%
# data1.info()
data1['User_Purchase_Frequency'].value_counts().plot(kind='bar',title='User Purchase Frequency')
# Out:
# <Axes: title={'center': 'User Purchase Frequency'}, xlabel='User_Purchase_Frequency'>

# %%
# data1.info()
data1['Logistics_Delay_Reason'].value_counts().plot(kind='bar', title='Logistics Delay Reason', color='purple')
# Out:
# <Axes: title={'center': 'Logistics Delay Reason'}, xlabel='Logistics_Delay_Reason'>

# %%
data1['Asset_Utilization'].plot(kind='hist', title='Asset Utilization')
# Out:
# <Axes: title={'center': 'Asset Utilization'}, ylabel='Frequency'>

# %%
data1.info()
data1['Demand_Forecast'].plot(kind='hist', title='Demand Forecast')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                1000 non-null   datetime64[ns]
#  1   Asset_ID                 1000 non-null   object
#  2   Latitude                 1000 non-null   float64
#  3   Longitude                1000 non-null   float64
#  4   Inventory_Level          1000 non-null   int64
#  5   Shipment_Status          1000 non-null   object
#  6   Temperature              1000 non-null   float64
#  7   Humidity                 1000 non-null   float64
#  8   Traffic_Status           1000 non-null   object
#  9   Waiting_Time             1000 non-null   int64
#  10  User_Transaction_Amount  1000 non-null   int64
#  11  User_Purchase_Frequency  1000 non-null   int64
#  12  Logistics_Delay_Reason   737 non-null    object
#  13  Asset_Utilization        1000 non-null   float64
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                1000 non-null   datetime64[ns]
#  1   Asset_ID                 1000 non-null   object
#  2   Latitude                 1000 non-null   float64
#  3   Longitude                1000 non-null   float64
#  4   Inventory_Level          1000 non-null   int64
#  5   Shipment_Status          1000 non-null   object
#  6   Temperature              1000 non-null   float64
#  7   Humidity                 1000 non-null   float64
#  8   Traffic_Status           1000 non-null   object
#  9   Waiting_Time             1000 non-null   int64
#  10  User_Transaction_Amount  1000 non-null   int64
#  11  User_Purchase_Frequency  1000 non-null   int64
#  12  Logistics_Delay_Reason   737 non-null    object
#  13  Asset_Utilization        1000 non-null   float64
# ...

# %% [markdown]
# **Analyz**

# %%
#Which trucks are most delayed
data1[data1['Shipment_Status'] == 'Delayed'].groupby(['Asset_ID','Shipment_Status'])['Shipment_Status'].count()
# Out:
# Asset_ID  Shipment_Status
# Truck_1   Delayed            30
# Truck_10  Delayed            40
# Truck_2   Delayed            34
# Truck_3   Delayed            33
# Truck_4   Delayed            41
# Truck_5   Delayed            33
# Truck_6   Delayed            31
# Truck_7   Delayed            36
# Truck_8   Delayed            39
# Truck_9   Delayed            33
# Name: Shipment_Status, dtype: int64

# %%
#Which trucks are most affected by traffic
data1.groupby(['Asset_ID', 'Traffic_Status'])['Traffic_Status'].count()
# Out:
# Asset_ID  Traffic_Status
# Truck_1   Clear             29
#           Detour            32
#           Heavy             28
# Truck_10  Clear             33
#           Detour            35
#           Heavy             37
# Truck_2   Clear             31
#           Detour            43
#           Heavy             31
# Truck_3   Clear             22
#           Detour            34
#           Heavy             37
# Truck_4   Clear             38
#           Detour            35
#           Heavy             34
# Truck_5   Clear             33
#           Detour            32
#           Heavy             28
# Truck_6   Clear             39
#           Detour            32
#           Heavy             32
# Truck_7   Clear             33
#           Detour            34
#           Heavy             35
# Truck_8   Clear             33
#           Detour            41
#           Heavy             35
# Truck_9   Clear             37
#           Detour            27
# ...

# %%
#Average and median waiting time by shipment status
data1.groupby('Shipment_Status')['Waiting_Time'].agg(['mean', 'median'])
# Out:
#                       mean  median
# Shipment_Status
# Delayed          34.560000    34.0
# Delivered        35.281065    35.0
# In Transit       35.387821    35.0

# %%
data1.groupby('Asset_ID')['Waiting_Time'].agg(['mean', 'median'])
# Out:
#                mean  median
# Asset_ID
# Truck_1   37.022472    36.0
# Truck_10  32.295238    32.0
# Truck_2   35.238095    34.0
# Truck_3   36.860215    38.0
# Truck_4   35.308411    35.0
# Truck_5   34.494624    35.0
# Truck_6   35.611650    35.0
# Truck_7   36.725490    38.5
# Truck_8   33.366972    31.0
# Truck_9   34.159574    34.0

# %%
                        #Требования к прогназированию
data1.groupby('Asset_ID')['Demand_Forecast'].agg(['mean', 'median'])
# Out:
#                 mean  median
# Asset_ID
# Truck_1   194.134831   191.0
# Truck_10  194.142857   203.0
# Truck_2   196.533333   188.0
# Truck_3   203.956989   215.0
# Truck_4   207.532710   213.0
# Truck_5   200.193548   204.0
# Truck_6   184.495146   180.0
# Truck_7   201.833333   202.5
# Truck_8   198.559633   201.0
# Truck_9   212.340426   218.0

# %%
data1.head()
# Out:
#             Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 0 2024-03-20 00:11:14   Truck_7  -65.7383    11.2497              390
# 1 2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 2 2024-07-29 18:42:48  Truck_10   54.9232    79.5455              190
# 3 2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 4 2024-09-27 15:52:58   Truck_7  -65.8477    47.9468              480
#
#   Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 0         Delayed         27.0      67.8         Detour            38
# 1      In Transit         22.5      54.3          Heavy            16
# 2      In Transit         25.2      62.2         Detour            34
# 3       Delivered         25.4      52.3          Heavy            37
# 4         Delayed         20.5      57.2          Clear            56
#
#    User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# ...

# %%
data1.columns
# Out:
# Index(['Timestamp', 'Asset_ID', 'Latitude', 'Longitude', 'Inventory_Level',
#        'Shipment_Status', 'Temperature', 'Humidity', 'Traffic_Status',
#        'Waiting_Time', 'User_Transaction_Amount', 'User_Purchase_Frequency',
#        'Logistics_Delay_Reason', 'Asset_Utilization', 'Demand_Forecast',
#        'Logistics_Delay', 'Location'],
#       dtype='object')

# %%
sns.pairplot(data1)
